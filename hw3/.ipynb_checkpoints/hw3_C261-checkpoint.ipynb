# %% [markdown]
# # Homework 3
#
# ## Problem 1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.neighbors import KernelDensity

# %% [markdown]
# ### Part (a)

# %%
# Generating samples from specified distribution
np.random.seed(5)
N = 100
k = np.random.binomial(1, 0.6, N)

X = np.zeros(N)

for i, j in enumerate(k):
    if j == 1: 
        X[i] = np.random.normal(-2, 1.5, 1)
    else: 
        X[i] = np.random.normal(3, 1.5, 1)
        
X = X[:, np.newaxis]

# %% [markdown]
# ### Part (b)

# %%
# Plot the kernel density
# Generate equally-spaced points for plotting true density
X_plot = np.linspace(-9, 10, 1000)[:, np.newaxis]

true_dens = (0.6 * norm(-2, 1.5).pdf(X_plot[:, 0])
             + 0.4 * norm(3, 1.5).pdf(X_plot[:, 0]))

fig, ax = plt.subplots()
ax.fill(X_plot[:, 0], true_dens, fc='black', alpha=0.2,
        label='input distribution')

# Fit the KDE model
kde = KernelDensity(kernel='gaussian', bandwidth=0.5).fit(X)
log_dens = kde.score_samples(X_plot)
ax.plot(X_plot[:, 0], np.exp(log_dens), '-',
        label="kernel = '{0}'".format('gaussian'))

ax.text(6, 0.38, "N={0} points".format(N))

ax.legend(loc='upper left')
ax.plot(X[:, 0], -0.005 - 0.01 * np.random.random(X.shape[0]), '+k')

ax.set_xlim(-9, 10)
ax.set_ylim(-0.02, 0.4)
plt.show()

# %% [markdown]
# ### Part (c)

# %%
# Only need to generate a new object kde1 and kde2

fig, ax = plt.subplots()
ax.fill(X_plot[:, 0], true_dens, fc='black', alpha=0.2,
        label='input distribution')


kde1 = KernelDensity(kernel='gaussian', bandwidth=2).fit(X)
log_dens1 = kde1.score_samples(X_plot)
kde2 = KernelDensity(kernel='gaussian', bandwidth=0.1).fit(X)
log_dens2 = kde2.score_samples(X_plot)

ax.plot(X_plot[:, 0], np.exp(log_dens1), '-',
        label="h = '{0}'".format('2'))
ax.plot(X_plot[:, 0], np.exp(log_dens2), '-',
        label="h = '{0}'".format('0.1'))

ax.text(6, 0.38, "N={0} points".format(N))

ax.legend(loc='upper left')
ax.plot(X[:, 0], -0.005 - 0.01 * np.random.random(X.shape[0]), '+k')

ax.set_xlim(-9, 10)
ax.set_ylim(-0.02, 0.4)
plt.title("KDE Plots")
plt.xlabel('x')
plt.ylabel('p(x)')
plt.show()

# %% [markdown]
# From the plot we can see that h = 0.1 is overfitting since it's very "noisy", and the blue line h = 2 is under fitting becasue it's way too smooth and doesn't capture the true trends accurately

# %% [markdown]
# ## Problem 2
# ### Part (a)

# %% [markdown]
# $P(y=1|x) > P(y=0|x)$ is equivalent to P(y=1|x) > 1/2, which is $\frac{1}{1+e^{-z}}>1/2\;$ => $\;e^{-z}<1 \;$ => $\; z>0$
#
# Therefore we have $1+2x_1+3x_2>0\;$ => $\; 2x_1+3x_2>-1$

# %% [markdown]
# ### Part (b)
# $P(y=1|x)>0.8\;$ => $\;\frac{1}{1+e^{-z}}>0.8\;$ => $\;1+e^{-z}<1.25\;$ => $\;e^{-z}<0.25$ => $e^{z}>4\;$ => $\;z>ln(4)=1.39\;$
# This is equivalent to $1+2x_1+3x_2>1.39\;$ => $\;2x_1+3x_2>0.39$

# %% [markdown]
# ### Part (c)
# From part (b) we have $2x_1+3x_2>0.39$ for $P(y=1|x)>0.8$
# Now if $x_2=0.5$ then $2x_1+1.5>0.39\;$ => $\;x_1>-0.56$

# %% [markdown]
# ## Problem 3
# ### Part (a)

# %%
np.random.seed(5)

N = 300
m1 = [0, 0]
m2 = [0, 1]
m3 = [1.5, 0]
cv1 = [[0.5, 0], [0, 0.5]]
cv2 = [[0.5, 0], [0, 1]]
cv3 = [[0.5, -0.25], [-0.25, 0.5]]

# Create the sample dataset matrix X and response y
X1 = np.random.multivariate_normal(m1, cv1, N)
X2 = np.random.multivariate_normal(m2, cv2, N)
X3 = np.random.multivariate_normal(m3, cv3, N)

y = [0]*N + [1]*N + [2]*N

# Plot the data points
plt.plot(X1[:,0], X1[:,1], ".", label = "Class 0")
plt.plot(X2[:,0], X2[:,1], ".", label = "Class 1")
plt.plot(X3[:,0], X3[:,1], ".", label = "Class 2")  


plt.text(1.8, 5.1, "N={0} points per class".format(N))
plt.legend(loc='best')
plt.xlabel('x0')
plt.ylabel('x1')
# Out:
# Text(0,0.5,'x1')

# %% [markdown]
# ### Part (b)

# %%
from itertools import product
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# Concatenate 3 classes into one dataset
X = np.concatenate((X1, X2, X3))
X_tr,X_ts, y_tr,y_ts = train_test_split(X, y, test_size = 0.5, random_state = 1)

# Create the classifier object
clf1 = KNeighborsClassifier(n_neighbors = 2)
clf2 = KNeighborsClassifier(n_neighbors = 5)
clf3 = KNeighborsClassifier(n_neighbors = 15)

clf1.fit(X_tr, y_tr)
clf2.fit(X_tr, y_tr)
clf3.fit(X_tr, y_tr)

# Plot decision regions
x1_min, x1_max = -3, 3
x2_min, x2_max = -2, 3
xx, yy = np.meshgrid(np.arange(x1_min, x1_max, 0.1),
                     np.arange(x2_min, x2_max, 0.1))

f, axarr = plt.subplots(2, 2, sharex='col', sharey='row', figsize=(10, 8))

for idx, clf, tt in zip(product([0, 1], [0, 1]),
                        [clf1, clf2, clf3],
                        ['k = 2', 'k = 5',
                         'k = 15']):

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    axarr[idx[0], idx[1]].contourf(xx, yy, Z, alpha=0.4)
    axarr[idx[0], idx[1]].scatter(X[:, 0], X[:, 1], c=y,
                                  s=20, edgecolor='k')
    axarr[idx[0], idx[1]].set_title(tt)
    axarr[idx[0], idx[1]].set_xlim(-3, 3)
    axarr[idx[0], idx[1]].set_ylim(-2, 3)

plt.show()

# %% [markdown]
# Above regions are plotted as required. Bottom right grid is left empty intentionally.

# %% [markdown]
# ### Part (c)

# %%
# Create an empty array to store results
mse = np.zeros(99)

# Cross validation
k_test = np.arange(2, 101)
for i, a in enumerate(k_test):
    
    # Fit the model given the current number of k
    clf = KNeighborsClassifier(n_neighbors = a)
    clf.fit(X_tr, y_tr)
    # Predicton testing data
    yhat = clf.predict(X_ts)
    # Calculate MSE
    mse[i] = np.mean((y_ts - yhat)**2)

# Plot the results
plt.plot(k_test, mse, '-')
plt.title("MSE vs. k")
plt.xlabel('k')
plt.ylabel('MSE')
# Out:
# Text(0,0.5,'MSE')

# %% [markdown]
# Looks like we have the lowest MSE when k is around 15-20. It is quite noisy since we didn't use K-fold validation.

# %% [markdown]
# ## Problem 4
# ### Part (a)

# %% [markdown]
# $$\frac{dz_i}{d\beta_0}=1$$
# $$\frac{dz_i}{d\beta_1}=x_{1i}$$
# $$\frac{dz_i}{d\beta_2}=x_{2i}$$

# %% [markdown]
# ### Part (b)
# Use chain rule
#
# $$\frac{dJ(\beta)}{d\beta_0}=\sum_i g'_i(z_i)\frac{dz_i}{d\beta_0} =\sum_i (\frac{e^{z_i}}{1+e^{z_i}}-y_i)\frac{dz_i}{d\beta_0}$$
#
# And use results from part (a)
#
# $$J'(\beta_0)=\sum_i^N (\frac{e^{z_i}}{1+e^{z_i}}-y_i)*1=\sum_i^N (\frac{e^{\beta_0+\beta_1x_{1i}+\beta_2x_{2i}}}{1+e^{\beta_0+\beta_1x_{1i}+\beta_2x_{2i}}}-y_i)$$
#
# Similarly
#
# $$J'(\beta_1)=\sum_i^N (\frac{e^{z_i}}{1+e^{z_i}}-y_i)*x_{1i}=\sum_i^N (\frac{x_{1i}e^{\beta_0+\beta_1x_{1i}+\beta_2x_{2i}}}{1+e^{\beta_0+\beta_1x_{1i}+\beta_2x_{2i}}}-y_ix_{1i})$$
#
# And
#
# $$J'(\beta_2)=\sum_i^N (\frac{e^{z_i}}{1+e^{z_i}}-y_i)*x_{2i}=\sum_i^N (\frac{x_{1i}e^{\beta_0+\beta_1x_{1i}+\beta_2x_{2i}}}{1+e^{\beta_0+\beta_1x_{1i}+\beta_2x_{2i}}}-y_ix_{2i})$$

# %% [markdown]
# ## Problem 5
# ### Part (a)

# %%
Xd = np.array([[30, 0], [50, 1], [70, 1], [80, 2], [100, 1]])
y = np.array([0, 1, 0, 1, 1])

#combine = [[30, 0, 0], [50, 1, 1], [70, 1, 0], [80, 2, 1], [100, 1, 1]]
fig, ax = plt.subplots()
for g in np.unique(y):
    i = np.where(y == g)
    plt.scatter(Xd[i, 0], Xd[i, 1], label = g, edgecolor='k')
    plt.yticks(np.arange(min(Xd[:, 1]), max(Xd[:, 1])+0.1, 1))
ax.legend()
plt.title("Donation Scatter Plot")
plt.xlabel('Income')
plt.ylabel('Similar Politicians')
plt.show()

# %% [markdown]
# ### Part (b)
#
# $$\hat{y_i}=I\{z_i>0\}\; where \; z_i=x_{i1}+x_{i2}-70$$
#
# Here the weight vector is just $(1, 1)^T\;$ and $\;b = -70$

# %% [markdown]
# ### Part (c)
#
# note that $P(y_i=1|X_i)$ is a monotonic function of $z_i$, when $P(y_i=1|X_i)$ is the smallest, $-z_i$ is the biggest. Therefore, from part (a), since both coefficients are positive, we pick the smallest $X_{i1}$ and $X_{i2}$, which is the first datum. It has income 30 and twitter follow 0.

# %% [markdown]
# ### Part (d)
#
# note that in (b) I specified $\hat{y_i}=I\{z_i*>0\}\; where \; z_i*=x_{i1}+x_{i2}-70$. If we use the new parameters it becomes $\hat{y_i}=I\{z_i*>0\}\; where \; z_i*=\alpha x_{i1}+\alpha x_{i2}-70\alpha=\alpha(x_{i1}+x_{i2}-70)$, but note that $\alpha(x_{i1}+x_{i2}-70)>0$ is equivalent to $(x_{i1}+x_{i2}-70)>0\;$. So it's essentially the same classifier. It did not change my classifier.
#
# In (c), however, $P(y_i=1|X_i)=\frac{1}{1+e^{-\alpha(x_{i1}+x_{i2}-70)}}=\frac{1}{1+e^{-\alpha z_i}}\ne\frac{1}{1+e^{-z_i}}$ is different since we added $\alpha$ as an extra power term

# %% [markdown]
# ## Problem 6
# ### Part (a)

# %%
import cv2

img = cv2.imread("birds.jpg")
plt.imshow(img)

# %% [markdown]
# ### Part (b)

# %%
nx = np.shape(img)[1]
ny = np.shape(img)[0]

img = np.array(img, dtype=np.float64) / 255
# Create an empty new matrix with correct dimensions, reserving memory, increasing efficiency
# Note that "img2" is my new matrix X
img2 = np.zeros((nx*ny, 3))

# Big Loop through rows
for i, row in enumerate(img):
    # In each row we loop through each column which contains the 3x1 color vectors
    for j, col in enumerate(row):
        # calculate the index for the current iteration's place in the new matrix
        ind = i*660+j
        # store the 3x1 color in the new matrix, with the correct location index
        img2[ind] = col
# Note that we can simply use reshape() here, but I wrote out the loops
        
# Convert to floating point      
#img2 = np.float32(img2)
# Check to confirm that the new matrix has the correct dimensions, nx*ny x 3
np.shape(img2)
# Out:
# (272580, 3)

# %% [markdown]
# ### Part (c)

# %%
from sklearn.cluster import KMeans as km

nc = 3
model = km(n_clusters=nc, random_state=0).fit(img2)

labels = model.predict(img2)

#codebook_random = shuffle(img2, random_state=0)[:nc + 1]
w = img.shape[0]
h = img.shape[1]
#d = img.shape[2]

d = model.cluster_centers_.shape[1]
new_img = np.zeros((w, h, d))
label_idx = 0
for i in range(w):
    for j in range(h):
        new_img[i][j] = model.cluster_centers_[labels[label_idx]]
        label_idx += 1

new_img = np.rint(new_img)

# For 5 clusters
nc = 5
model = km(n_clusters=nc, random_state=0).fit(img2)

labels = model.predict(img2)

d = model.cluster_centers_.shape[1]
new_img2 = np.zeros((w, h, d))
label_idx = 0
for i in range(w):
    for j in range(h):
        new_img2[i][j] = model.cluster_centers_[labels[label_idx]]
        label_idx += 1

new_img2 = np.rint(new_img2)

plt.figure(1)
plt.clf()
plt.axis('off')
plt.title('Original image (96,615 colors)')
plt.imshow(img)

plt.figure(2)
plt.clf()
plt.axis('off')
plt.title('Quantized image (3 clusters, K-Means)')
plt.imshow(new_img)

plt.figure(3)
plt.clf()
plt.axis('off')
plt.title('Quantized image (5 clusters, K-Means)')
plt.imshow(new_img2)

# %% [markdown]
# ### Part (d)
#
# It seems that with bigger numbers of clusters we get better immages. These clusters act like "important colors". If we capter only two most important colors it will look like a black-white image like the second one. With 2 more colors, we get a much better image (3rd one). With inreased clusters, we will get closer to the original image
