# %% [markdown]
# # Homework 3
#
# ## Problem 1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.neighbors import KernelDensity

# %% [markdown]
# ### Part (a)

# %%
# Generating samples from specified distribution
# np.random.seed(5)
k = np.random.binomial(1, 0.6, 100)
#X = np.where(k == 1, np.random.normal(-2, 1.5**2, 1), 
             #np.random.normal(3, 1.5**2, 1))[:, np.newaxis]

X = np.concatenate((np.random.normal(-2, 1.5**2, int(0.6 * N)),
                    np.random.normal(3, 1.5**2, int(0.4 * N))))[:, np.newaxis]

# %% [markdown]
# ### Part (b)

# %%
# Plot the kernel density
N = 100
np.random.seed(1)


X_plot = np.linspace(-9, 10, 1000)[:, np.newaxis]

true_dens = (0.6 * norm(-2, 1.5**2).pdf(X_plot[:, 0])
             + 0.4 * norm(3, 1.5**2).pdf(X_plot[:, 0]))

fig, ax = plt.subplots()
ax.fill(X_plot[:, 0], true_dens, fc='black', alpha=0.2,
        label='input distribution')


kde = KernelDensity(kernel='gaussian', bandwidth=0.5).fit(X)
log_dens = kde.score_samples(X_plot)
ax.plot(X_plot[:, 0], np.exp(log_dens), '-',
        label="kernel = '{0}'".format('gaussian'))

ax.text(6, 0.38, "N={0} points".format(N))

ax.legend(loc='upper left')
ax.plot(X[:, 0], -0.005 - 0.01 * np.random.random(X.shape[0]), '+k')

ax.set_xlim(-9, 10)
ax.set_ylim(-0.02, 0.4)
plt.show()

# %% [markdown]
# ### Part (c)
